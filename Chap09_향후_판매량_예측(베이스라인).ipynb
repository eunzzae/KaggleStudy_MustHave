# %% [markdown]
# <a href="https://colab.research.google.com/github/eunzzae/KaggleStudy_MustHave/blob/main/Chap09_%ED%96%A5%ED%9B%84_%ED%8C%90%EB%A7%A4%EB%9F%89_%EC%98%88%EC%B8%A1(%EB%B2%A0%EC%9D%B4%EC%8A%A4%EB%9D%BC%EC%9D%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 베이스라인 모델

# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings(action='ignore') # 경고 문구 생략

# 데이터 경로
data_path = '/content/drive/MyDrive/[캐글] 스터디_musthave/data/competitive-data-science-predict-future-sales/'

sales_train = pd.read_csv(data_path + 'sales_train.csv')
shops = pd.read_csv(data_path + 'shops.csv')
items = pd.read_csv(data_path + 'items.csv')
item_categories = pd.read_csv(data_path + 'item_categories.csv')
test = pd.read_csv(data_path + 'test.csv')
sample_submission = pd.read_csv(data_path + 'sample_submission.csv')

# %% [markdown]
# ## 1) 피처엔지니어링 1 : 피처명 한글화

# %%
sales_train = sales_train.rename(columns={'date': '날짜',
                                          'date_block_num':'월ID',
                                          'shop_id': '상점ID',
                                          'item_id':'상품ID',
                                          'item_price':'판매가',
                                          'item_cnt_day':'판매량'})
sales_train.head()
# Out:
#            날짜  월ID  상점ID   상품ID      판매가  판매량
# 0  02.01.2013    0    59  22154   999.00  1.0
# 1  03.01.2013    0    25   2552   899.00  1.0
# 2  05.01.2013    0    25   2552   899.00 -1.0
# 3  06.01.2013    0    25   2554  1709.05  1.0
# 4  15.01.2013    0    25   2555  1099.00  1.0

# %%
shops = shops.rename(columns={'shop_name':'상점명',
                              'shop_id':'상점ID'})

shops.head()
# Out:
#                               상점명  상점ID
# 0   !Якутск Орджоникидзе, 56 фран     0
# 1   !Якутск ТЦ "Центральный" фран     1
# 2                Адыгея ТЦ "Мега"     2
# 3  Балашиха ТРК "Октябрь-Киномир"     3
# 4        Волжский ТЦ "Волга Молл"     4

# %%
items = items.rename(columns={'item_name':'상품명',
                      'item_id':'상품ID',
                      'item_category_id':'상품분류ID'})
items.head()
# Out:
#                                                  상품명  상품ID  상품분류ID
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D     0      40
# 1  !ABBYY FineReader 12 Professional Edition Full...     1      76
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D     2      40
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D     3      40
# 4        ***КОРОБКА (СТЕКЛО)                       D     4      40

# %%
item_categories = item_categories.rename(columns={'item_category_name':'상품분류명',
                                'item_category_id':'상품분류ID'})

# %%
test=test.rename(columns={'shop_id':'상점ID',
                     'item_id':'상품ID'})
test.head()
# Out:
#    ID  상점ID  상품ID
# 0   0     5  5037
# 1   1     5  5320
# 2   2     5  5233
# 3   3     5  5232
# 4   4     5  5268

# %% [markdown]
# ## 2) 피처엔지니어링2 : 데이터 다운캐스팅
# - 더 작은 데이터 타입으로 변환하는 작업

# %%
def downcast(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        dtype_name = df[col].dtype.name
        if dtype_name == 'object':
            pass
        elif dtype_name == 'bool':
            df[col] = df[col].astype('int8')
        elif dtype_name.startswith('int') or (df[col].round() == df[col]).all():
            df[col] = pd.to_numeric(df[col], downcast='integer')
        else:
            df[col] = pd.to_numeric(df[col], downcast='float')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print('{:.1f}% 압축됨'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
all_df = [sales_train, shops, items, item_categories, test]

for df in all_df:
  df = downcast(df)
# Out:
# 54.2% 압축됨
# 38.6% 압축됨
# 54.2% 압축됨
# 39.9% 압축됨
# 70.8% 압축됨

# %% [markdown]
# ## 3) 피처엔지니어링3 : 데이터 조합 생성

# %%
from itertools import product

# %%
train = []

# 월ID, 상점ID, 상품ID 조합 생성
for i in sales_train['월ID'].unique():
  all_shop = sales_train.loc[sales_train['월ID']==i, '상점ID'].unique()
  all_item = sales_train.loc[sales_train['월ID']==i, '상품ID'].unique()
  train.append(np.array(list(product([i], all_shop, all_item))))

# %%
idx_features = ['월ID', '상점ID', '상품ID'] # 기준 피처

# 리스트 타입인 train을 DataFrame 타입으로 변환
train = pd.DataFrame(np.vstack(train), columns=idx_features)

# %% [markdown]
# ## 4) 피처엔지니어링4 : 타깃값(월간 판매량) 추가

# %%
# idx_features 를 기준으로 그룹화해 판매량 합 구하기
group = sales_train.groupby(idx_features).agg({'판매량':'sum'})

# 인덱스 재설정
group = group.reset_index()

# 피처명을 '판매량'에서 '월간 판매량'으로 변경
group = group.rename(columns={'판매량':'월간 판매량'})

group
# Out:
#          월ID  상점ID   상품ID  월간 판매량
# 0          0     0     32       6
# 1          0     0     33       3
# 2          0     0     35       1
# 3          0     0     43       1
# 4          0     0     51       2
# ...      ...   ...    ...     ...
# 1609119   33    59  22087       6
# 1609120   33    59  22088       2
# 1609121   33    59  22091       1
# 1609122   33    59  22100       1
# 1609123   33    59  22102       1
#
# [1609124 rows x 4 columns]

# %%
# train 과 group 병합하기
train = train.merge(group, on=idx_features, how='left')
train
# Out:
#           월ID  상점ID   상품ID  월간 판매량
# 0           0    59  22154     1.0
# 1           0    59   2552     NaN
# 2           0    59   2554     NaN
# 3           0    59   2555     NaN
# 4           0    59   2564     NaN
# ...       ...   ...    ...     ...
# 10913845   33    21   7635     NaN
# 10913846   33    21   7638     NaN
# 10913847   33    21   7640     NaN
# 10913848   33    21   7632     NaN
# 10913849   33    21   7440     NaN
#
# [10913850 rows x 4 columns]

# %% [markdown]
# * 가비지 컬렉션

# %%
import gc # 가비지 컬렉터 불러오기

del group # 더는 사용하지 않는 변수 지정
gc.collect(); # 가비지 컬렉션 수행

# %% [markdown]
# ## 5) 피처엔지니어링5 : 테스트 데이터 이어붙이기

# %%
test['월ID'] = 34

# %%
all_data = pd.concat([train, test.drop('ID', axis=1)],
          ignore_index = True, # 기존 인덱스 무시(0부터 새로 시작)
          keys=idx_features) # 이어붙이는 기준이 되는 피처

# %%
all_data = all_data.fillna(0)
all_data
# Out:
#           월ID  상점ID   상품ID  월간 판매량
# 0           0    59  22154     1.0
# 1           0    59   2552     0.0
# 2           0    59   2554     0.0
# 3           0    59   2555     0.0
# 4           0    59   2564     0.0
# ...       ...   ...    ...     ...
# 11128045   34    45  18454     0.0
# 11128046   34    45  16188     0.0
# 11128047   34    45  15757     0.0
# 11128048   34    45  19648     0.0
# 11128049   34    45    969     0.0
#
# [11128050 rows x 4 columns]

# %% [markdown]
# ## 6) 피처엔지니어링6 : 나머지 데이터 병합(최종 데이터 생성)

# %%
# 나머지 데이터 병합
all_data = all_data.merge(shops, on='상점ID', how='left')
all_data = all_data.merge(items, on='상품ID', how='left')
all_data = all_data.merge(item_categories, on='상품분류ID', how='left')

# 데이터 다운캐스팅
all_data = downcast(all_data)

# 가비지 컬렉션
del shops, items, item_categories
gc.collect();
# Out:
# 31.1% 압축됨

# %%
all_data.head()
# Out:
#    월ID  상점ID   상품ID  월간 판매량                     상점명  \
# 0    0    59  22154       1  Ярославль ТЦ "Альтаир"
# 1    0    59   2552       0  Ярославль ТЦ "Альтаир"
# 2    0    59   2554       0  Ярославль ТЦ "Альтаир"
# 3    0    59   2555       0  Ярославль ТЦ "Альтаир"
# 4    0    59   2564       0  Ярославль ТЦ "Альтаир"
#
#                                                  상품명  상품분류ID
# 0                                  ЯВЛЕНИЕ 2012 (BD)      37
# 1           DEEP PURPLE  The House Of Blue Light  LP      58
# 2           DEEP PURPLE  Who Do You Think We Are  LP      58
# 3            DEEP PURPLE 30 Very Best Of 2CD (Фирм.)      56
# 4  DEEP PURPLE Perihelion: Live In Concert DVD (К...      59

# %%
all_data = all_data.drop(['상점명','상품명','상품분류ID'],axis=1)

# %% [markdown]
# ## 7) 피처엔지니어링7 : 마무리

# %% [markdown]
# * 훈련 데이터 : `13년 1월부터 `15년 9월(월ID=32)까지 판매 내역
# * 검증 데이터 : `15년 10월 (월ID=33)판매내역
# * 테스트 데이터 : `15년 11월 (월ID=34) 판매내역

# %%
# 훈련 데이터 (피처)
X_train = all_data[all_data['월ID']<33]
X_train = X_train.drop(['월간 판매량'], axis=1)

# 검증데이터 (피처)
X_valid = all_data[all_data['월ID'] == 33]
X_valid = X_valid.drop(['월간 판매량'], axis=1)

# 테스트 데이터(피처)
X_test = all_data[all_data['월ID'] == 34]
X_test = X_test.drop(['월간 판매량'], axis=1)

# 훈련 데이터 (타깃값)
y_train = all_data[all_data['월ID'] < 33]['월간 판매량']
y_train = y_train.clip(0, 20) # 타깃값을 0~20으로 제한

# 검증 데이터(타깃값)
y_valid = all_data[all_data['월ID'] == 33]['월간 판매량']
y_valid = y_valid.clip(0, 20)

# %%
del all_data
gc.collect();

# %% [markdown]
# ## 8) 피처엔지니어링8 : 모델 훈련 및 성능 검증

# %%
X_train.head()
# Out:
#    월ID  상점ID   상품ID
# 0    0    59  22154
# 1    0    59   2552
# 2    0    59   2554
# 3    0    59   2555
# 4    0    59   2564

# %%
import lightgbm as lgb

# LightGBM용 하이퍼파라미터
params = {'metric':'rmse',
          'num_leaves':255,
          'learning_rate':0.01,
          'force_col_wise':True,
          'random_state':10}

# 범주형 피처 설정
cat_features = ['상점ID', '상품분류ID']

# LightGBM용 훈련 및 검증 데이터 셋
dtrain = lgb.Dataset(X_train, y_train)
dvalid = lgb.Dataset(X_valid, y_valid)

# %%
# LightGBM 모델 훈련
lgb = lgb.train(params=params,
                train_set=dtrain,
                num_boost_round=500,
                valid_sets=(dtrain, dvalid),
                categorical_feature=cat_features)
                # verbose_eval=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-22562e613fa8> in <cell line: 2>()
#       1 # LightGBM 모델 훈련
# ----> 2 lgb = lgb.train(params=params,
#       3                 train_set=dtrain,
#       4                 num_boost_round=500,
#       5                 valid_sets=(dtrain, dvalid),
#
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     243     # construct booster
#     244     try:
# --> 245         booster = Booster(params=params, train_set=train_set)
#     246         if is_valid_contain_train:
#     247             booster.set_train_data_name(train_data_name)
#
# ...

# %%
pred = lgb_model.predict(X_test).clip(0, 20)

submission['item_cnt_montuh'] = preds
submission.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-0bad38950aa5> in <cell line: 1>()
# ----> 1 pred = lgb_model.predict(X_test).clip(0, 20)
#       2
#       3 submission['item_cnt_montuh'] = preds
#       4 submission.to_csv('submission.csv', index=False)
#
# NameError: name 'lgb_model' is not defined
